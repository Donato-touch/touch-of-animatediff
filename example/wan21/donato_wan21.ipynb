# %%
# @title 구글드라이브 연동 + 준비 (1회 실행)

COMFY_TAG = "v0.3.18"
MGR_TAG = "3.27.2"

RUN_COLAB_COMMAND = f"python donato_wan21.py --run-step 1 --comfy-tag {COMFY_TAG} --mgr-tag {MGR_TAG}"

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %cd /content/drive/MyDrive/comfy_donato_wan
# !$RUN_COLAB_COMMAND

# %%
# @title RUN! (1회당 1개씩 나옴, output으로 자동 저장)

MODEL_NAME = "wan2.1_i2v_720p_14B_bf16.safetensors"
INPUT_IMAGE = "tatsumaki.png"  # @param {type:"string"}
POSITIVE_PROMPT = "an anime girl dancing"  # @param {type:"string"}
NEGATIVE_PROMPT = "Bright tones, overexposed, static, blurry details, subtitles, style, work, painting, image, still, overall grayish, worst quality, low quality, JPEG compression artifacts, ugly, incomplete, extra fingers, poorly drawn hands, poorly drawn face, deformed, disfigured, distorted limbs, fused fingers, motionless image, cluttered background, three legs, crowded background, walking backward."  # @param {type:"string"}
# @markdown 4의 배수 + 1
VIDEO_LENGTH = 61  # @param {type:"integer"}
VIDEO_WIDTH = 512  # @param {type:"integer"}
VIDEO_HEIGHT = 768  # @param {type:"integer"}
VIDEO_FRAME_RATE = 15  # @param {type:"integer"}

# @markdown 음수: 랜덤, 0이상: 고정
SAMPLER_SEED = -1  # @param {type:"integer"}
SAMPLER_STEPS = 15  # @param {type:"integer"}
SAMPLER_CFG = 6.0  # @param {type:"number"}
SAMPLER_DENOISE = 1.0  # @param {type:"number"}

# @markdown 생성 완료 후 코랩 종료
TERMINATE_COLAB = False  # @param {type:"boolean"}

RUN_COLAB_COMMAND2 = f'python donato_wan21.py --run-step 2 --comfy-tag {COMFY_TAG} --mgr-tag {MGR_TAG} --model-name "{MODEL_NAME}" --positive-prompt "{POSITIVE_PROMPT}" --negative-prompt "{NEGATIVE_PROMPT}" --width {VIDEO_WIDTH} --height {VIDEO_HEIGHT} --length {VIDEO_LENGTH} --input-img-name {INPUT_IMAGE} --seed {SAMPLER_SEED} --steps {SAMPLER_STEPS} --cfg {SAMPLER_CFG} --denoise {SAMPLER_DENOISE} --output-frame-rate {VIDEO_FRAME_RATE} {"--terminate-colab" if TERMINATE_COLAB else ""}'

# %cd /content/drive/MyDrive/comfy_donato_wan
# !$RUN_COLAB_COMMAND2

from IPython.display import Video
preview_video_path = '/usr/local/comfy/preview.mp4'
Video(preview_video_path, embed=True, width=512, html_attributes="controls loop muted autoplay")
